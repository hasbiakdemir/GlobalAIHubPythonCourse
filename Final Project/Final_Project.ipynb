# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
s1 = "Python nedir?"
c1 = "Bir programlama dili"

s2 = "Python ismi nereden gelmektedir?"
c2 = "Monty Python"

s3 = "Python kim tarafından geliştirildi?"
c3 = "Guido Van Rossum"

s4 = "Python hangi programlama dili ile yazıldı?"
c4 = "C"

s5 = "Python'da fonksiyonlar birden çok değer dönebilir mi?"
c5 = "Evet"

s6 = "Python'da kaç tane döngü bulunur? - Sayı girilmelidir."
c6 = "2"

s7 = "Global AI Hub'ın sloganı nedir?"
c7 = "Build Your Future"

s8 = "Global AI Hub merkezi neresidir?"
c8 = "İsviçre"

s9 = "Bu projenin verildiği kursun adı nedir?"
c9 = "Introduction to Python Programming"

s10 = "RPA açılımı nedir?"
c10 = "Robotic Process Automation"

# %%
sorular = [s1, s2, s3, s4, s5, s6, s7, s8, s9, s10]
cevaplar = [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10]
sc = {'SORU': sorular, 'CEVAP': cevaplar}

# %%
df = pd.DataFrame(sc)
#df = df.style.set_properties(**{'text-align': 'left'})
print(df.index)
df

# %%
a = ""
cevap = []
sayi = 0

while True:
    for i in range(len(df)):
        print(df['SORU'].iloc[i])
        a = input("Cevap (Çıkmak için q'ya basın): ")
        if a == "q":
            break
        harf_i = ["i", "ı", "I", "İ"]
        for j in range(len(harf_i)):
            a = a.replace(harf_i[j], "İ")
            j += 1
        cevap.append(a)
        if (cevap[i].upper() == df['CEVAP'].iloc[i].upper().replace("I", "İ")):
            sayi += 10
        i += 1

    if (sayi <= 50):
        print("\n\nTesti geçemediniz.\nPuan: ", sayi)
    else:
        print("\n\nTebrikler.\nPuan: ", sayi)
        
    komut = ["E", "H"]
    print("\nYeniden denemek ister misiniz?")
    restart = input("\nE: Evet - H: Hayır: ")
    
    while restart not in komut:
        print("Yanlış değer girdiniz. Tekrar Deneyiniz.")
        restart = input("\nE: Evet - H: Hayır: ")
        
    if (restart == "E"):
        continue
    else:
        print("Çıkış yaptınız. Teşekkürler.")
        break
